# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/data-for-datavis/iris_versicolor.csv
# /kaggle/input/data-for-datavis/candy.csv
# /kaggle/input/data-for-datavis/iris_virginica.csv
# /kaggle/input/data-for-datavis/museum_visitors.csv
# /kaggle/input/data-for-datavis/cancer_m.csv
# /kaggle/input/data-for-datavis/spotify.csv
# /kaggle/input/data-for-datavis/ign_scores.csv
# /kaggle/input/data-for-datavis/flight_delays.csv
# /kaggle/input/data-for-datavis/iris_setosa.csv
# /kaggle/input/data-for-datavis/fifa.csv
# /kaggle/input/data-for-datavis/iris.csv
# /kaggle/input/data-for-datavis/cancer_b.csv
# /kaggle/input/data-for-datavis/insurance.csv
# /kaggle/input/fifa-world-cup/WorldCups.csv
# /kaggle/input/fifa-world-cup/WorldCupMatches.csv
# /kaggle/input/fifa-world-cup/WorldCupPlayers.csv

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fifa =  pd.read_csv('../input/fifa-world-cup/WorldCupMatches.csv' , index_col ='Datetime' , parse_dates=True )
fifa.head()
# Out:
#                        Year    Stage         Stadium         City  \
# Datetime
# 1930-07-13 15:00:00  1930.0  Group 1         Pocitos  Montevideo
# 1930-07-13 15:00:00  1930.0  Group 4  Parque Central  Montevideo
# 1930-07-14 12:45:00  1930.0  Group 2  Parque Central  Montevideo
# 1930-07-14 14:50:00  1930.0  Group 3         Pocitos  Montevideo
# 1930-07-15 16:00:00  1930.0  Group 1  Parque Central  Montevideo
#
#                     Home Team Name  Home Team Goals  Away Team Goals  \
# Datetime
# 1930-07-13 15:00:00         France              4.0              1.0
# 1930-07-13 15:00:00            USA              3.0              0.0
# 1930-07-14 12:45:00     Yugoslavia              2.0              1.0
# 1930-07-14 14:50:00        Romania              3.0              1.0
# 1930-07-15 16:00:00      Argentina              1.0              0.0
#
#                     Away Team Name Win conditions  Attendance  \
# Datetime
# ...

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=fifa.Attendance)

# %%
file=pd.read_csv('../input/data-for-datavis/spotify.csv', index_col='Date' , parse_dates=True)
file.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
plt.figure(figsize=(15,10))
plt.title('spotify')
sns.lineplot(data=file['Despacito'] , label='despacito')
sns.lineplot(data=file['HUMBLE.'] , label='humble')
plt.xlabel('DATE')
# Out:
# Text(0.5, 0, 'DATE')

# %%
flight_filepath = '../input/data-for-datavis/flight_delays.csv'
flight_data = pd.read_csv(flight_filepath , index_col='Month')

# %%
flight_data.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
plt.figure(figsize=(15,10))
plt.title('arrival delay')
sns.barplot(x=flight_data.index , y=flight_data.EV)
plt.ylabel('arrival delay in min')
# Out:
# Text(0, 0.5, 'arrival delay in min')

# %%
plt.figure(figsize=(15,10))
plt.title('arrival delay of each airline by month')
sns.heatmap(data = flight_data , annot=True) #by keeping annot true , it shows the values in the heat map
plt.xlabel('airline')
# Out:
# Text(0.5, 69.0, 'airline')

# %%
insurance_filepath = '../input/data-for-datavis/insurance.csv'
data = pd.read_csv(insurance_filepath )

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x=data.bmi , y=data.charges)

# %%
sns.regplot(x=data.bmi , y=data.charges)

# %%
sns.scatterplot(x=data['bmi'], y=data['charges'], hue=data['smoker'])

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=data)

# %%
sns.swarmplot(x=data['smoker'],
              y=data['charges'])

# %%
iris_data = pd.read_csv('../input/data-for-datavis/iris.csv' , index_col ='Id')
iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %%
sns.distplot(a=iris_data['Petal Length (cm)'])

# %%
sns.distplot(a=iris_data['Petal Length (cm)'],kde=False)    #a for choosing column

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'] , shade=False)

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'] , shade=True)

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'] , y=iris_data['Sepal Width (cm)'] , kind='kde')

# %%
iris_set_filepath = "../input/data-for-datavis/iris_setosa.csv"
iris_ver_filepath = "../input/data-for-datavis/iris_versicolor.csv"
iris_vir_filepath = "../input/data-for-datavis/iris_virginica.csv"

iris_set_data = pd.read_csv(iris_set_filepath, index_col="Id")
iris_ver_data = pd.read_csv(iris_ver_filepath, index_col="Id")
iris_vir_data = pd.read_csv(iris_vir_filepath, index_col="Id")

# Print the first 5 rows of the Iris versicolor data
iris_ver_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 51                7.0               3.2                4.7               1.4
# 52                6.4               3.2                4.5               1.5
# 53                6.9               3.1                4.9               1.5
# 54                5.5               2.3                4.0               1.3
# 55                6.5               2.8                4.6               1.5
#
#             Species
# Id
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor

# %%
sns.distplot(a=iris_set_data['Petal Length (cm)'], label="Iris-setosa", kde=False)
sns.distplot(a=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", kde=False)
sns.distplot(a=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", kde=False)

# Add title
plt.title("Histogram of Petal Lengths, by Species")

# Force legend to appear
plt.legend()

# %%
sns.kdeplot(data=iris_set_data['Petal Length (cm)'], label="Iris-setosa", shade=True)
sns.kdeplot(data=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", shade=True)
sns.kdeplot(data=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", shade=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species")
